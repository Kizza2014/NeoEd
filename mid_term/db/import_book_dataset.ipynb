# %%
import pandas as pd
from pymongo import MongoClient

# %%
client = MongoClient("mongodb://127.0.0.1:27017/?directConnection=true&serverSelectionTimeoutMS=2000&appName=mongosh+2.3.1")

# %%
books = pd.read_json("https://raw.githubusercontent.com/ozlerhakan/mongodb-json-files/master/datasets/books.json", lines=True)

# %%
books
# Out:
#                                       _id  \
# 0                                       1
# 1                                       2
# 2                                       3
# 3                                       4
# 4                                       5
# ..                                    ...
# 426  {'$oid': '53c2ae8528d75d572c06adb8'}
# 427  {'$oid': '53c2ae8528d75d572c06adb9'}
# 428  {'$oid': '53c2ae8528d75d572c06adba'}
# 429  {'$oid': '53c2ae8528d75d572c06adbb'}
# 430  {'$oid': '53c2ae8528d75d572c06adbc'}
#
#                                          title           isbn  pageCount  \
# 0                            Unlocking Android     1933988673        416
# 1            Android in Action, Second Edition     1935182722        592
# 2                     Specification by Example     1617290084          0
# 3                             Flex 3 in Action     1933988746        576
# 4                             Flex 4 in Action     1935182420        600
# ..                                         ...            ...        ...
# 426                             DSLs in Action     1935182455        376
# 427  Database Programming for Handheld Devices     1884777856          0
# 428           Jakarta Commons Online Bookshelf     1932394524        402
# 429                   Browsing with HttpClient  1932394524a-e          0
# 430               Codec: Encoders and Decoders  1932394524j-e          0
#
#                                  publishedDate  \
# 0    {'$date': '2009-04-01T00:00:00.000-0700'}
# 1    {'$date': '2011-01-14T00:00:00.000-0800'}
# 2    {'$date': '2011-06-03T00:00:00.000-0700'}
# 3    {'$date': '2009-02-02T00:00:00.000-0800'}
# 4    {'$date': '2010-11-15T00:00:00.000-0800'}
# ..                                         ...
# 426  {'$date': '2010-12-01T00:00:00.000-0800'}
# 427  {'$date': '2000-07-01T00:00:00.000-0700'}
# 428  {'$date': '2005-03-01T00:00:00.000-0800'}
# 429  {'$date': '2005-03-01T00:00:00.000-0800'}
# 430  {'$date': '2005-03-01T00:00:00.000-0800'}
#
#                                           thumbnailUrl  \
# 0    https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 1    https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 2    https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 3    https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 4    https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# ..                                                 ...
# 426  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 427  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 428  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 429  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 430  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
#
#                                       shortDescription  \
# 0    Unlocking Android: A Developer's Guide provide...
# 1    Android in Action, Second Edition is a compreh...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 426  DSLs in Action introduces the concepts and def...
# 427                                                NaN
# 428                                                NaN
# 429  Written for developers and architects with rea...
# 430                                                NaN
#
#                                        longDescription   status  \
# 0    Android is an open source mobile phone platfor...  PUBLISH
# 1    When it comes to mobile apps, Android can do a...  PUBLISH
# 2                                                  NaN  PUBLISH
# 3    New web applications require engaging user-fri...  PUBLISH
# 4    Using Flex, you can create high-quality, effec...  PUBLISH
# ..                                                 ...      ...
# 426  On any given day, a developer may encounter a ...  PUBLISH
# 427                                                NaN  PUBLISH
# 428  Written for developers and architects with rea...  PUBLISH
# 429                                                NaN  PUBLISH
# 430                                                NaN  PUBLISH
#
#                                                authors              categories
# 0        [W. Frank Ableson, Charlie Collins, Robi Sen]   [Open Source, Mobile]
# 1                         [W. Frank Ableson, Robi Sen]                  [Java]
# 2                                        [Gojko Adzic]  [Software Engineering]
# 3          [Tariq Ahmed with Jon Hirschi, Faisal Abid]              [Internet]
# 4    [Tariq Ahmed, Dan Orlando, John C. Bland II, J...              [Internet]
# ..                                                 ...                     ...
# 426                                                 []                      []
# 427                                                 []                      []
# 428                                                 []                      []
# 429                                                 []                      []
# 430                                                 []                      []
#
# [431 rows x 11 columns]

# %%
# clean the isbn column to ensure correct format
import re

def clean_isbn(data):
  val=re.sub(r'[^0-9]', '', str(data))
  return val

books['isbn'].astype(str)
books['isbn']=books['isbn'].apply(clean_isbn)

# %%
books
# Out:
#                                       _id  \
# 0                                       1
# 1                                       2
# 2                                       3
# 3                                       4
# 4                                       5
# ..                                    ...
# 426  {'$oid': '53c2ae8528d75d572c06adb8'}
# 427  {'$oid': '53c2ae8528d75d572c06adb9'}
# 428  {'$oid': '53c2ae8528d75d572c06adba'}
# 429  {'$oid': '53c2ae8528d75d572c06adbb'}
# 430  {'$oid': '53c2ae8528d75d572c06adbc'}
#
#                                          title        isbn  pageCount  \
# 0                            Unlocking Android  1933988673        416
# 1            Android in Action, Second Edition  1935182722        592
# 2                     Specification by Example  1617290084          0
# 3                             Flex 3 in Action  1933988746        576
# 4                             Flex 4 in Action  1935182420        600
# ..                                         ...         ...        ...
# 426                             DSLs in Action  1935182455        376
# 427  Database Programming for Handheld Devices  1884777856          0
# 428           Jakarta Commons Online Bookshelf  1932394524        402
# 429                   Browsing with HttpClient  1932394524          0
# 430               Codec: Encoders and Decoders  1932394524          0
#
#                                  publishedDate  \
# 0    {'$date': '2009-04-01T00:00:00.000-0700'}
# 1    {'$date': '2011-01-14T00:00:00.000-0800'}
# 2    {'$date': '2011-06-03T00:00:00.000-0700'}
# 3    {'$date': '2009-02-02T00:00:00.000-0800'}
# 4    {'$date': '2010-11-15T00:00:00.000-0800'}
# ..                                         ...
# 426  {'$date': '2010-12-01T00:00:00.000-0800'}
# 427  {'$date': '2000-07-01T00:00:00.000-0700'}
# 428  {'$date': '2005-03-01T00:00:00.000-0800'}
# 429  {'$date': '2005-03-01T00:00:00.000-0800'}
# 430  {'$date': '2005-03-01T00:00:00.000-0800'}
#
#                                           thumbnailUrl  \
# 0    https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 1    https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 2    https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 3    https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 4    https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# ..                                                 ...
# 426  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 427  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 428  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 429  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 430  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
#
#                                       shortDescription  \
# 0    Unlocking Android: A Developer's Guide provide...
# 1    Android in Action, Second Edition is a compreh...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 426  DSLs in Action introduces the concepts and def...
# 427                                                NaN
# 428                                                NaN
# 429  Written for developers and architects with rea...
# 430                                                NaN
#
#                                        longDescription   status  \
# 0    Android is an open source mobile phone platfor...  PUBLISH
# 1    When it comes to mobile apps, Android can do a...  PUBLISH
# 2                                                  NaN  PUBLISH
# 3    New web applications require engaging user-fri...  PUBLISH
# 4    Using Flex, you can create high-quality, effec...  PUBLISH
# ..                                                 ...      ...
# 426  On any given day, a developer may encounter a ...  PUBLISH
# 427                                                NaN  PUBLISH
# 428  Written for developers and architects with rea...  PUBLISH
# 429                                                NaN  PUBLISH
# 430                                                NaN  PUBLISH
#
#                                                authors              categories
# 0        [W. Frank Ableson, Charlie Collins, Robi Sen]   [Open Source, Mobile]
# 1                         [W. Frank Ableson, Robi Sen]                  [Java]
# 2                                        [Gojko Adzic]  [Software Engineering]
# 3          [Tariq Ahmed with Jon Hirschi, Faisal Abid]              [Internet]
# 4    [Tariq Ahmed, Dan Orlando, John C. Bland II, J...              [Internet]
# ..                                                 ...                     ...
# 426                                                 []                      []
# 427                                                 []                      []
# 428                                                 []                      []
# 429                                                 []                      []
# 430                                                 []                      []
#
# [431 rows x 11 columns]

# %%
# # rows with null values

# books[books['isbn'].isnull()]
# books[books['isbn'].isnull() == True]
# books[books.isbn.isnull()]
# books[books.isbn.isnull() == True]

# %%
books
# Out:
#                                       _id  \
# 0                                       1
# 1                                       2
# 2                                       3
# 3                                       4
# 4                                       5
# ..                                    ...
# 426  {'$oid': '53c2ae8528d75d572c06adb8'}
# 427  {'$oid': '53c2ae8528d75d572c06adb9'}
# 428  {'$oid': '53c2ae8528d75d572c06adba'}
# 429  {'$oid': '53c2ae8528d75d572c06adbb'}
# 430  {'$oid': '53c2ae8528d75d572c06adbc'}
#
#                                          title        isbn  pageCount  \
# 0                            Unlocking Android  1933988673        416
# 1            Android in Action, Second Edition  1935182722        592
# 2                     Specification by Example  1617290084          0
# 3                             Flex 3 in Action  1933988746        576
# 4                             Flex 4 in Action  1935182420        600
# ..                                         ...         ...        ...
# 426                             DSLs in Action  1935182455        376
# 427  Database Programming for Handheld Devices  1884777856          0
# 428           Jakarta Commons Online Bookshelf  1932394524        402
# 429                   Browsing with HttpClient  1932394524          0
# 430               Codec: Encoders and Decoders  1932394524          0
#
#                                  publishedDate  \
# 0    {'$date': '2009-04-01T00:00:00.000-0700'}
# 1    {'$date': '2011-01-14T00:00:00.000-0800'}
# 2    {'$date': '2011-06-03T00:00:00.000-0700'}
# 3    {'$date': '2009-02-02T00:00:00.000-0800'}
# 4    {'$date': '2010-11-15T00:00:00.000-0800'}
# ..                                         ...
# 426  {'$date': '2010-12-01T00:00:00.000-0800'}
# 427  {'$date': '2000-07-01T00:00:00.000-0700'}
# 428  {'$date': '2005-03-01T00:00:00.000-0800'}
# 429  {'$date': '2005-03-01T00:00:00.000-0800'}
# 430  {'$date': '2005-03-01T00:00:00.000-0800'}
#
#                                           thumbnailUrl  \
# 0    https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 1    https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 2    https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 3    https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 4    https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# ..                                                 ...
# 426  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 427  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 428  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 429  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 430  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
#
#                                       shortDescription  \
# 0    Unlocking Android: A Developer's Guide provide...
# 1    Android in Action, Second Edition is a compreh...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 426  DSLs in Action introduces the concepts and def...
# 427                                                NaN
# 428                                                NaN
# 429  Written for developers and architects with rea...
# 430                                                NaN
#
#                                        longDescription   status  \
# 0    Android is an open source mobile phone platfor...  PUBLISH
# 1    When it comes to mobile apps, Android can do a...  PUBLISH
# 2                                                  NaN  PUBLISH
# 3    New web applications require engaging user-fri...  PUBLISH
# 4    Using Flex, you can create high-quality, effec...  PUBLISH
# ..                                                 ...      ...
# 426  On any given day, a developer may encounter a ...  PUBLISH
# 427                                                NaN  PUBLISH
# 428  Written for developers and architects with rea...  PUBLISH
# 429                                                NaN  PUBLISH
# 430                                                NaN  PUBLISH
#
#                                                authors              categories
# 0        [W. Frank Ableson, Charlie Collins, Robi Sen]   [Open Source, Mobile]
# 1                         [W. Frank Ableson, Robi Sen]                  [Java]
# 2                                        [Gojko Adzic]  [Software Engineering]
# 3          [Tariq Ahmed with Jon Hirschi, Faisal Abid]              [Internet]
# 4    [Tariq Ahmed, Dan Orlando, John C. Bland II, J...              [Internet]
# ..                                                 ...                     ...
# 426                                                 []                      []
# 427                                                 []                      []
# 428                                                 []                      []
# 429                                                 []                      []
# 430                                                 []                      []
#
# [431 rows x 11 columns]

# %%
books.iloc[0, books.columns.get_loc('thumbnailUrl')]
# Out:
# 'https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ.book-thumb-images/ableson.jpg'

# %%
# adding some more attributes

books['available_copies'] = 15
books['borrowed_copies'] = 0

# %%
books.columns
# Out:
# Index(['_id', 'title', 'isbn', 'pageCount', 'publishedDate', 'thumbnailUrl',
#        'shortDescription', 'longDescription', 'status', 'authors',
#        'categories', 'available_copies', 'borrowed_copies'],
#       dtype='object')

# %%
# insert to mongoDB
import math

db = client['test']
collection = db['books']

books_list = []
        
for index, row in books.iterrows():
    book = {
        'title': row['title'],
        'isbn': row['isbn'],
        'authors': row['authors'],
        'categories': row['categories'],
        'status': row['status'],
        'available_copies': row['available_copies'],
        'borrowed_copies': row['borrowed_copies'],
        'ratings': []
    }

    # optional attributes and can be nan
    if not math.isnan(row['pageCount']):
        book['page_count'] = row['pageCount']
    if isinstance(row['publishedDate'], dict):
        mongo_date = row['publishedDate']['$date']
        year = int(mongo_date[0:4])
        book['published_year'] = year
    if isinstance(row['thumbnailUrl'], str):
        book['thumbnail_url'] = row['thumbnailUrl']
    if isinstance(row['shortDescription'], str):
        book['short_description'] = row['shortDescription']
    if isinstance(row['longDescription'], str):
        book['long_description'] = row['longDescription']
    
    books_list.append(book)

collection.insert_many(books_list)
# Out:
# InsertManyResult([ObjectId('66f814e5bd8b5eb51b3709ca'), ObjectId('66f814e5bd8b5eb51b3709cb'), ObjectId('66f814e5bd8b5eb51b3709cc'), ObjectId('66f814e5bd8b5eb51b3709cd'), ObjectId('66f814e5bd8b5eb51b3709ce'), ObjectId('66f814e5bd8b5eb51b3709cf'), ObjectId('66f814e5bd8b5eb51b3709d0'), ObjectId('66f814e5bd8b5eb51b3709d1'), ObjectId('66f814e5bd8b5eb51b3709d2'), ObjectId('66f814e5bd8b5eb51b3709d3'), ObjectId('66f814e5bd8b5eb51b3709d4'), ObjectId('66f814e5bd8b5eb51b3709d5'), ObjectId('66f814e5bd8b5eb51b3709d6'), ObjectId('66f814e5bd8b5eb51b3709d7'), ObjectId('66f814e5bd8b5eb51b3709d8'), ObjectId('66f814e5bd8b5eb51b3709d9'), ObjectId('66f814e5bd8b5eb51b3709da'), ObjectId('66f814e5bd8b5eb51b3709db'), ObjectId('66f814e5bd8b5eb51b3709dc'), ObjectId('66f814e5bd8b5eb51b3709dd'), ObjectId('66f814e5bd8b5eb51b3709de'), ObjectId('66f814e5bd8b5eb51b3709df'), ObjectId('66f814e5bd8b5eb51b3709e0'), ObjectId('66f814e5bd8b5eb51b3709e1'), ObjectId('66f814e5bd8b5eb51b3709e2'), ObjectId('66f814e5bd8b5eb51b3709e3'), ObjectId('66f814e5bd8b5eb51b3709e4'), ObjectId('66f814e5bd8b5eb51b3709e5'), ObjectId('66f814e5bd8b5eb51b3709e6'), ObjectId('66f814e5bd8b5eb51b3709e7'), ObjectId('66f814e5bd8b5eb51b3709e8'), ObjectId('66f814e5bd8b5eb51b3709e9'), ObjectId('66f814e5bd8b5eb51b3709ea'), ObjectId('66f814e5bd8b5eb51b3709eb'), ObjectId('66f814e5bd8b5eb51b3709ec'), ObjectId('66f814e5bd8b5eb51b3709ed'), ObjectId('66f814e5bd8b5eb51b3709ee'), ObjectId('66f814e5bd8b5eb51b3709ef'), ObjectId('66f814e5bd8b5eb51b3709f0'), ObjectId('66f814e5bd8b5eb51b3